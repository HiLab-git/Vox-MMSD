# %%
import numpy as np
import matplotlib.pyplot as plt


image=np.random.rand(4,96,96,96)
c, d, h, w = image.shape

mask = (np.zeros(image.shape)==1)
mod_mask = np.random.rand(4)>(1-0.5)
mask[mod_mask,:] = True


image[mask] = 0.0
plt.imshow(image[0][48])
plt.show()
plt.imshow(image[1][48])
plt.show()
plt.imshow(image[2][48])
plt.show()
plt.imshow(image[3][48])
plt.show()
